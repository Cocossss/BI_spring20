# %%
from IPython.display import Image

# %% [markdown]
# 1. Оценка качества исправления ошибок
#
# Исправить риды с помощью двух программ, и приложив их и исходные риды к геному, оценить некоторые значения

# %% [markdown]
# #### Попробуем trimmomatic

# %%
# !java -jar ./trimmomatic-0.39.jar PE -phred33 ./data/ecoli_400K_err_1.fastq.gz ./data/ecoli_400K_err_2.fastq.gz -baseout ./data/corrected SLIDINGWINDOW:10:30
# Out:
# TrimmomaticPE: Started with arguments:
#  -phred33 ./data/ecoli_400K_err_1.fastq.gz ./data/ecoli_400K_err_2.fastq.gz -baseout ./data/corrected SLIDINGWINDOW:10:30
# Multiple cores found: Using 4 threads
# Using templated Output files: ./data/corrected_1P ./data/corrected_1U ./data/corrected_2P ./data/corrected_2U
# Input Read Pairs: 1381602 Both Surviving: 1290989 (93,44%) Forward Only Surviving: 49095 (3,55%) Reverse Only Surviving: 30063 (2,18%) Dropped: 11455 (0,83%)
# TrimmomaticPE: Completed successfully

# %%
Image('./corrected1.png')
